# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
PATH = './data'
manuel = PATH + '/codeBook_v3.csv'
kp2020 = PATH + '/KP2020.csv'
kp2021 = PATH + '/KP2021.csv'
npa2020 = PATH + '/NPA2020.csv'

# %%
npa2020 = pd.read_csv(npa2020, encoding='cp949')
kp2021 = pd.read_csv(kp2021, encoding='cp949')
kp2020 = pd.read_csv(kp2020, encoding='cp949')

# %%
list(npa2020.columns)
# Out:
# ['RECV_CPLT_DT',
#  'RECV_CPLT_TM',
#  'NPA_CL',
#  'EVT_STAT_CD',
#  'EVT_CL_CD',
#  'RPTER_SEX',
#  'HPPN_OLD_ADDR',
#  'HPPN_X',
#  'HPPN_Y',
#  'SME_EVT_YN']

# %%
new_columns = [list(npa2020.columns)[1], list(npa2020.columns)[0]] + list(npa2020.columns)[2:]
new_columns
# Out:
# ['RECV_CPLT_TM',
#  'RECV_CPLT_DT',
#  'NPA_CL',
#  'EVT_STAT_CD',
#  'EVT_CL_CD',
#  'RPTER_SEX',
#  'HPPN_OLD_ADDR',
#  'HPPN_X',
#  'HPPN_Y',
#  'SME_EVT_YN']

# %%
npa2020[[list(npa2020.columns)[1], list(npa2020.columns)[0]] + list(npa2020.columns)[2:]]
# Out:
#          RECV_CPLT_TM  RECV_CPLT_DT  NPA_CL  EVT_STAT_CD  EVT_CL_CD RPTER_SEX  \
# 0                   7      20200101      13           10        501         2
# 1                 132      20200101      13           10        501         1
# 2                  39      20200101      13           10        501         1
# 3                 110      20200101      13           10        601         3
# 4                 342      20200101      13           10        601         1
# ...               ...           ...     ...          ...        ...       ...
# 1178239          3505      20201122      19           10        501         1
# 1178240          5213      20201122      13           10        601
# 1178241          4627      20201122      19           10        601         1
# 1178242          5246      20201122      19            5        301         1
# 1178243          1134      20201122      13           10        601
#
# ...

# %%
kp2020
# Out:
#       RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  \
# 0              충남청  20/12/01 01:43:07.000000000      19           10
# 1              대전청  20/12/01 02:05:04.000000000      13           10
# 2              대전청  20/12/01 02:06:52.000000000      13           10
# 3              충남청  20/12/01 02:37:25.000000000      19           10
# 4              충남청  20/12/01 08:17:50.000000000      19           10
# ...            ...                          ...     ...          ...
# 77072          충남청  20/12/31 01:18:16.000000000      19           10
# 77073          충남청  20/12/31 01:17:45.000000000      19           10
# 77074          충남청  20/12/31 00:13:50.000000000      19           10
# 77075          대전청  20/12/31 00:49:29.000000000      13           10
# 77076          대전청  20/12/31 00:49:06.000000000      13           10
#
#        EVT_CL_CD  RPTER_SEX                   HPPN_PNU_ADDR      HPPN_X  \
# ...

# %%
kp2021
# Out:
#         RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  \
# 0                대전청  21/03/07 00:00:01.000000000      13           10
# 1                대전청  21/03/07 00:02:13.000000000      13           10
# 2                대전청  21/03/07 00:00:33.000000000      13           10
# 3                대전청  21/03/07 00:01:18.000000000      13           10
# 4                대전청  21/03/07 00:01:43.000000000      13           10
# ...              ...                          ...     ...          ...
# 2594055          대전청  23/01/12 11:23:09.000000000      13           10
# 2594056          충남청  23/01/16 11:59:47.000000000      19           10
# 2594057          충남청  23/01/16 11:58:54.000000000      19           10
# 2594058          충남청  23/01/14 01:00:47.000000000      19           10
# 2594059          대전청  23/01/14 01:22:31.000000000      13           10
#
#          EVT_CL_CD  RPTER_SEX                    HPPN_PNU_ADDR      HPPN_X  \
# ...

# %%
kp2020.iloc[:,2:]
# Out:
#        NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0          19           10        305        1.0
# 1          13           10        601        3.0
# 2          13           10        601        1.0
# 3          19           10        606        3.0
# 4          19           10        401        2.0
# ...       ...          ...        ...        ...
# 77072      19           10        302        2.0
# 77073      19           10        501        3.0
# 77074      19           10        604        3.0
# 77075      13           10        302        2.0
# 77076      13           10        601        3.0
#
#                         HPPN_PNU_ADDR      HPPN_X     HPPN_Y SME_EVT_YN
# 0           충청남도 보령시 궁촌동(행정:대천4동) 369  126.598345  36.341537          Y
# 1                                 NaN  127.404663  36.341685        NaN
# 2                                 NaN  127.404663  36.341685        NaN
# 3            충청남도 보령시 천북면 하만리 628-10   126.524980  36.474390          N
# ...

# %%
concat_df = pd.concat([kp2020.iloc[:,2:],kp2021.iloc[:,2:],npa2020.iloc[:,2:]])

# %%
concat_df.__len__()
# Out:
# 3849381

# %%
concat_df.loc[concat_df.duplicated()]
# Out:
#          NPA_CL  EVT_STAT_CD  EVT_CL_CD RPTER_SEX HPPN_PNU_ADDR      HPPN_X  \
# 23           13           10        501       1.0           NaN  127.404663
# 27           13           10        501       1.0           NaN  127.404663
# 43           13           10        601       3.0           NaN  127.404663
# 48           13           10        501       1.0           NaN  127.404663
# 49           13           10        601       3.0           NaN  127.404663
# ...         ...          ...        ...       ...           ...         ...
# 1178238      19            7        201         1           NaN  127.187027
# 1178239      19           10        501         1           NaN         NaN
# 1178240      13           10        601                     NaN  127.404663
# 1178241      19           10        601         1           NaN         NaN
# 1178243      13           10        601                     NaN  127.404663
#
# ...

# %%
kp2020.loc[kp2020.duplicated(keep=False)]
# Out:
#       RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  \
# 3195           대전청  20/12/02 20:43:48.000000000      13           10
# 3196           대전청  20/12/02 20:43:48.000000000      13           10
# 9708           대전청  20/12/05 10:07:00.000000000       8           10
# 9735           대전청  20/12/05 10:07:00.000000000       8           10
# 18336          충남청  20/12/10 12:19:47.000000000      19           10
# ...            ...                          ...     ...          ...
# 72500          충남청  20/12/31 15:47:21.000000000      19           10
# 74904          충남청  20/12/31 21:43:43.000000000      19           10
# 74986          충남청  20/12/31 21:43:43.000000000      19           10
# 75974          대전청  20/12/30 11:30:24.000000000      13           10
# 75975          대전청  20/12/30 11:30:24.000000000      13           10
#
#        EVT_CL_CD  RPTER_SEX                 HPPN_PNU_ADDR      HPPN_X  \
# ...

# %%
kp2020.loc[kp2020['EVT_CL_CD'] == 215]
# Out:
#       RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  \
# 333            충남청  20/12/01 15:06:38.000000000      19           10
# 360            충남청  20/12/01 14:53:20.000000000      19           10
# 367            충남청  20/12/01 11:15:43.000000000      19           10
# 372            충남청  20/12/01 13:08:09.000000000      19           10
# 375            충남청  20/12/01 14:00:07.000000000      19           10
# ...            ...                          ...     ...          ...
# 76199          충남청  20/12/30 14:33:04.000000000      31           10
# 76473          대전청  20/12/30 14:54:23.000000000      13           10
# 76506          대전청  20/12/30 14:42:30.000000000      13           10
# 76673          대전청  20/12/30 17:18:28.000000000      13           10
# 76725          대전청  20/12/30 18:07:00.000000000      13           10
#
#        EVT_CL_CD  RPTER_SEX                           HPPN_PNU_ADDR  \
# 333          215        1.0         충청남도 아산시 온천동(온양1동) 1556(신학산텔레콤)
# ...

# %%
kp2020.loc[kp2020['EVT_CL_CD'] == 401]
# Out:
#       RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  \
# 4              충남청  20/12/01 08:17:50.000000000      19           10
# 9              대전청  20/12/01 07:08:44.000000000      13           10
# 10             대전청  20/12/01 07:09:20.000000000      13           10
# 31             충남청  20/12/01 01:36:38.000000000      19           10
# 53             대전청  20/12/01 01:39:03.000000000      13           10
# ...            ...                          ...     ...          ...
# 76995          충남청  20/12/31 00:33:54.000000000      19           10
# 76998          충남청  20/12/31 00:34:45.000000000      19           10
# 77036          대전청  20/12/31 01:08:43.000000000      13           10
# 77068          대전청  20/12/31 01:17:01.000000000      13           10
# 77069          대전청  20/12/31 01:18:53.000000000      13           10
#
#        EVT_CL_CD  RPTER_SEX                   HPPN_PNU_ADDR      HPPN_X  \
# ...

# %%
import folium

# %%
ta_df = kp2020.loc[kp2020['EVT_CL_CD'] == 215].iloc[:,7:9].dropna()
ta_df
# Out:
#            HPPN_X     HPPN_Y
# 333    127.001705  36.786898
# 360    127.052120  36.470196
# 367    127.251164  36.395766
# 372    127.012487  36.849074
# 375    127.140700  36.802345
# ...           ...        ...
# 76199  127.328548  36.481983
# 76473  127.403003  36.309410
# 76506  127.404978  36.320104
# 76673  127.425543  36.362818
# 76725  127.425682  36.454188
#
# [1637 rows x 2 columns]

# %%
for _, coord in enumerate(ta_df.values.tolist()):
    print(coord[::-1])
# Out:
# [36.786898, 127.001705]
# [36.47019614, 127.05211953]
# [36.395766, 127.251164]
# [36.849074, 127.012487]
# [36.802345, 127.1407]
# [36.717605, 126.280111]
# [36.813471, 127.135654]
# [36.71373, 126.54494]
# [36.414901, 126.945108]
# [36.918228, 126.73137]
# [36.77721, 126.95321]
# [36.123187, 127.441372]
# [36.810329, 127.144836]
# [36.385379, 127.378069]
# [36.472479, 127.133479]
# [36.895029, 126.632882]
# [36.372807, 126.649185]
# [36.912711, 127.221744]
# [36.744535, 126.863625]
# [37.52058, 126.967568]
# [36.484783, 127.145756]
# [36.77242, 126.99708]
# [36.3705556, 127.4272222]
# [36.30065588, 127.3440478]
# [36.777356, 126.50554]
# [36.89564, 126.632837]
# [36.93131398, 127.03737234]
# [36.663677, 126.713821]
# [36.712383, 126.545601]
# [36.92729, 127.03661]
# [36.89564, 126.632837]
# [36.934115, 127.057351]
# [36.158292, 127.102763]
# [36.800665, 127.14516]
# [36.19451385, 127.08825711]
# [36.600434, 126.665909]
# [36.663677, 126.713821]
# [36.60564414, 127.29649031]
# ...

# %%
latitude, longitude = 36.826718, 127.137160
m = folium.Map(location=[latitude, longitude],
               zoom_start=9, 
               width=750, 
               height=500
              )
for _, coord in enumerate(ta_df.values.tolist()):
    folium.Marker(location=coord[::-1]).add_to(m)
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
