# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
PATH = './data'
KP_ACC_PATH = PATH+'/kp_acc.csv'
KP_VOICE_PATH = PATH+'/kp_voice.csv'
NPA_ACC_PATH = PATH+'/npa_acc.csv'
NPA_VOICE_PATH = PATH+'/npa_voice.csv'

# %%
kp_acc = pd.read_csv(KP_ACC_PATH, encoding='utf-8')
kp_voice = pd.read_csv(KP_VOICE_PATH, encoding='utf-8')
npa_acc = pd.read_csv(NPA_ACC_PATH, encoding='utf-8')
npa_acc=npa_acc.loc[npa_acc['HPPN_X'] != 0.0]
npa_voice = pd.read_csv(NPA_VOICE_PATH, encoding='utf-8')

# %%
print(f"kp_acc len : {kp_acc.__len__()}")
print(f"kp_voice len : {kp_voice.__len__()}")
print(f"npa_acc len : {npa_acc.__len__()}")
print(f"npa_voice len : {npa_voice.__len__()}")
# Out:
# kp_acc len : 285756
# kp_voice len : 29794
# npa_acc len : 137449
# npa_voice len : 10664

# %%
kp_acc
# Out:
#        RECV_DEPT_NM  RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0               충남청    1606778270      19           10        401          2
# 1               대전청    1606760666      13           10        406          1
# 2               충남청    1606775838      19           10        402          1
# 3               대전청    1606774124      13           10        401          1
# 4               대전청    1606774160      13           10        401          2
# ...             ...           ...     ...          ...        ...        ...
# 285751          대전청    1673780499      13           10        401          1
# 285752          충남청    1673872016      19           10        401          1
# 285753          충남청    1673625768      19           10        403          2
# 285754          대전청    1673685338      13           10        401          1
# 285755          대전청    1673712800      13           10        401          1
#
# ...

# %%
npa_acc
# Out:
#         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0         1577806360      13           10        402          1
# 1         1577806532      13           10        406          1
# 2         1577805695      13           10        401          1
# 3         1577806981      13           10        401          1
# 4         1577871815      13           10        401          3
# ...              ...     ...          ...        ...        ...
# 140939    1605972007      13            7        406          1
# 140940    1605973208      13            5        401          1
# 140941    1605974239      19            5        406          3
# 140942    1605973073      13            5        401          1
# 140943    1605971722      19            7        406          1
#
#                         HPPN_OLD_ADDR      HPPN_X     HPPN_Y
# 0            대전광역시 서구 탄방동(탄방동) 1447-1  127.386345  36.346855
# 1         대전광역시 유성구 궁동(행정:온천2동) 423-8  127.349990  36.360798
# ...

# %%
kp_acc_none_loca = kp_acc.loc[kp_acc['HPPN_PNU_ADDR'] == '0'].reset_index()
kp_acc_none_loca
# Out:
#        index RECV_DEPT_NM  RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 0         93          대전청    1606800527      13           10        401
# 1        101          대전청    1606801513      13           10        401
# 2        102          대전청    1606800246      13           10        401
# 3        112          대전청    1606787810      13           10        403
# 4        157          대전청    1606811749      13           10        403
# ...      ...          ...           ...     ...          ...        ...
# 5743  285172          대전청    1673747629      13           10        401
# 5744  285220          대전청    1673858204      13           10        401
# 5745  285407          대전청    1673499431      13           10        401
# 5746  285704          대전청    1674049288      13           10        401
# 5747  285746          대전청    1673683324      13           10        401
#
#       RPTER_SEX HPPN_PNU_ADDR     HPPN_X     HPPN_Y
# ...

# %%
npa_acc_none_loca = npa_acc.loc[npa_acc['HPPN_OLD_ADDR'] == '0'].reset_index()
npa_acc_none_loca
# Out:
#       index  RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0         5    1577872007      13           10        403          1
# 1        28    1577869127      13           10        401          1
# 2        40    1577842878      13           10        401          1
# 3       337    1577919827      13           10        402          2
# 4       344    1577953958      13           10        402          1
# ...     ...           ...     ...          ...        ...        ...
# 1409  82433    1594029063      19           10        403          1
# 1410  82531    1593650003      19           10        402          2
# 1411  88417    1594282704      19           10        401          1
# 1412  88708    1594095122      19           10        401          1
# 1413  90508    1595754269      19           10        401          1
#
#      HPPN_OLD_ADDR      HPPN_X     HPPN_Y
# 0                0  127.404660  36.341686
# 1                0  127.404660  36.341686
# ...

# %%
npa_acc_none_loca
# Out:
#       index  RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0         5    1577872007      13           10        403          1
# 1        28    1577869127      13           10        401          1
# 2        40    1577842878      13           10        401          1
# 3       337    1577919827      13           10        402          2
# 4       344    1577953958      13           10        402          1
# ...     ...           ...     ...          ...        ...        ...
# 1409  82433    1594029063      19           10        403          1
# 1410  82531    1593650003      19           10        402          2
# 1411  88417    1594282704      19           10        401          1
# 1412  88708    1594095122      19           10        401          1
# 1413  90508    1595754269      19           10        401          1
#
#      HPPN_OLD_ADDR      HPPN_X     HPPN_Y
# 0                0  127.404660  36.341686
# 1                0  127.404660  36.341686
# ...

# %%
from PyKakao import Local
LOCAL = Local(service_key = "b2b4d096044642add00262c75e4a6006")

# %%
npa_acc_none_loca_long_lati = npa_acc_none_loca.iloc[:, -2:].values.tolist()
npa_acc_none_loca_addr = []
for long, lati in npa_acc_none_loca_long_lati:
    npa_acc_none_loca_addr.append(LOCAL.geo_coord2address(long, lati, dataframe=True)['address'][0].__getitem__('address_name'))

# %%
npa_acc_none_loca_addr
# Out:
# ['대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '충남 천안시 서북구 성정동 1506',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
# ...

# %%
kp_acc_none_loca_loca_long_lati = kp_acc_none_loca.iloc[:, -2:].values.tolist()
kp_acc_none_loca_loca_addr = []
for long, lati in kp_acc_none_loca_loca_long_lati:
    kp_acc_none_loca_loca_addr.append(LOCAL.geo_coord2address(long, lati, dataframe=True)['address'][0].__getitem__('address_name'))

# %%
kp_acc_none_loca_loca_addr
# Out:
# ['대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
#  '대전 중구 중촌동 253-2',
# ...

# %%
pd.DataFrame(npa_acc_none_loca_addr).to_csv('./data/npa_acc_none_loca_addr.csv', index=False)

# %%
pd.DataFrame(kp_acc_none_loca_loca_addr).to_csv('./data/kp_acc_none_loca_loca_addr.csv', index=False)

# %%
# long, lati = 127.386345, 36.346855
# LOCAL.geo_coord2address(long, lati, dataframe=True)['address'][0].__getitem__('address_name')
# Out:
# '대전 서구 탄방동 1447-1'

# %%
# LOCAL = Local(service_key = "b2b4d096044642add00262c75e4a6006")
# LOCAL.geo_coord2address(127.137160,36.826717, dataframe=True)['address'][0]
# Out:
# {'address_name': '충남 천안시 서북구 성정동 1259',
#  'region_1depth_name': '충남',
#  'region_2depth_name': '천안시 서북구',
#  'region_3depth_name': '성정동',
#  'mountain_yn': 'N',
#  'main_address_no': '1259',
#  'sub_address_no': '',
#  'zip_code': ''}

# %%
# Out:
#       index  RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  RPTER_SEX  \
# 0         5    1577872007      13           10        403          1
# 1        28    1577869127      13           10        401          1
# 2        40    1577842878      13           10        401          1
# 3       337    1577919827      13           10        402          2
# 4       344    1577953958      13           10        402          1
# ...     ...           ...     ...          ...        ...        ...
# 1409  82433    1594029063      19           10        403          1
# 1410  82531    1593650003      19           10        402          2
# 1411  88417    1594282704      19           10        401          1
# 1412  88708    1594095122      19           10        401          1
# 1413  90508    1595754269      19           10        401          1
#
#      HPPN_OLD_ADDR      HPPN_X     HPPN_Y
# 0                0  127.404660  36.341686
# 1                0  127.404660  36.341686
# ...
